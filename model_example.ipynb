# %%
import sir_bcm as sbcm
import numpy as np

# %%
#Parameters
N = 100
timestemps = 1000
epsilon = 0.3
mu = 0.05

# Example: Simulate the model for 100 timesteps and visualize results
activity, influences, t_stop = sbcm.model.run_model(N, timestemps, epsilon, mu)
sbcm.plotting.visualize_mean_and_std(activity)
sbcm.plotting.visualize_sample_opinions_all(activity, influences, 20)
